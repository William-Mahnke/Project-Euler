# %% [markdown]
# ## Permuted Multiples
#
# It can be seen the number, 125874, and its double, 251748, contain exactly the same digits, but in a different order.
#
# Find the smallest positive integer, x, such that 2x, 3x, 4x, 5x, and 6x, contain the same digits.
#
# ### Methodology
#
# Given an integer x, we can first easily compute the subsequent values. We can then convert the integers to a string and then to a list of the digits as individual string characters. If the numbers have the same digits, then the sorted lists of the digits (as strings) should be identical. Additionally, using the communtative property, we can just check x against all of the multiples rather than every combination. To speed this comparison up, or at least minimize the number of comparisons we're making, we can use nested if-else statements.
#
# ### WIP
