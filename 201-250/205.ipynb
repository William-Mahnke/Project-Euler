# %% [markdown]
# ## Dice Game
#
# Peter has nine four-sided (pyramidal) dice, each with faces numbered 1, 2, 3, 4.
# Colin has six six-sided (cubic) dice, each with faces numbered 1, 2, 3, 4, 5, 6.
#
# Peter and Colin roll their dice and compare totals: the highest total wins. The result is a draw if the totals are equal.
#
# What is the probability that Pyramidal Peter beats Cubic Colin? Give your answer rounded to seven decimal places in the form 0.abcdefg.

# %%
import random

# %%
# function for round of dice-rolling
def game():
    # roll for Peter
    peter = sum([random.randint(1,4) for i in range(9)])
    # roll for Colin
    colin = sum([random.randint(1,6) for i in range(6)])
    return 1 if peter > colin else 0

# %%
# loop through game until probability requirement is satisfied
count = 0
wins = 0
while True:
    wins += game()
    count += 1
    if count % 1000000 == 0:
        print(f'Games played: {count}, Peter Win %: {wins/count}')
# Out:
# Games played: 1000000, Peter Win %: 0.573432
# Games played: 2000000, Peter Win %: 0.5729385
# Games played: 3000000, Peter Win %: 0.573019
# Games played: 4000000, Peter Win %: 0.57320275
# Games played: 5000000, Peter Win %: 0.5732232
# Games played: 6000000, Peter Win %: 0.5732385
# Games played: 7000000, Peter Win %: 0.573254
# Games played: 8000000, Peter Win %: 0.57324575
# Games played: 9000000, Peter Win %: 0.5732216666666666
# Games played: 10000000, Peter Win %: 0.5731881
# Games played: 11000000, Peter Win %: 0.5732266363636364
# Games played: 12000000, Peter Win %: 0.5731830833333333
# Games played: 13000000, Peter Win %: 0.5731772307692308
# Games played: 14000000, Peter Win %: 0.5731684285714286
# Games played: 15000000, Peter Win %: 0.573153
# Games played: 16000000, Peter Win %: 0.5731495625
# Games played: 17000000, Peter Win %: 0.5732013529411765
# Games played: 18000000, Peter Win %: 0.5731723333333333
# Games played: 19000000, Peter Win %: 0.5732163157894736
# ...
